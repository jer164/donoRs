# %%
from virginia import virginia

va_path = "/Users/jacksonrudoff/donoRs/testing_area/states/VA/don_scott_2022.xml"

# %%
df = virginia(va_path)

# %%
df.drop('Address', axis=1)
# Out:
#     TransactionDate  Amount  TotalToDate  IsIndividual   LastName  \
# 14       2022-09-20  1000.0       1000.0          True      Aston
# 19       2022-07-15  1000.0       1000.0          True     Belote
# 21       2022-12-31   500.0        500.0          True      Bezik
# 22       2022-08-17   125.0        125.0          True      Brown
# 36       2022-08-15   125.0        125.0          True     Cooper
# 37       2022-08-31   250.0        250.0          True   Cornetta
# 39       2022-11-16  2500.0       2500.0          True  Davenport
# 45       2022-11-03   250.0        250.0          True     Easley
# 46       2022-11-08   250.0        250.0          True  Edmondson
# 50       2022-12-30   250.0        250.0          True     Fatehi
# 52       2022-09-25  1000.0       1000.0          True      Foley
# 53       2022-08-17   250.0        250.0          True      Fraim
# 54       2022-08-10   250.0        250.0          True    Frazier
# ...
